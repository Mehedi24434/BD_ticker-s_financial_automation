# %%
import functions as f

# %%
pdf_file = "./samples/sample13.pdf"
output_pdf = "pnl_page_searchable.pdf"
f.save_best_pnl_page_as_searchable_pdf(pdf_file, output_pdf, rotation_option=False, dpi=300)
# Out:
# Top pages by header score (page → header_score):
#   Page 2 → 10
#   Page 1 → 6
#   Page 3 → 5
#   Page 4 → 5
#   Page 14 → 4
#   Page 15 → 4
#   Page 5 → 3
#   Page 6 → 3
#   Page 8 → 3
#   Page 16 → 3
#   Page 17 → 3
#   Page 9 → 2
#   Page 10 → 2
#   Page 12 → 2
#   Page 13 → 2
#   Page 7 → 1
#   Page 11 → 1
#
# Term scores among header Top-K (page → term_score):
#   Page 2 → 18
#   Page 1 → 3
#   Page 3 → 3
#   Page 4 → 3
#   Page 14 → 1
#   Page 15 → 1
#   Page 5 → 1
#   Page 6 → 1
#   Page 8 → 1
#   Page 16 → 3
#   Page 17 → 0
#   Page 9 → 4
#   Page 10 → 4
#   Page 12 → 1
#   Page 13 → 1
#   Page 7 → 0
#   Page 11 → 0
#
# ✅ Most likely P&L page: Page 2 (term score: 18)
# ✅ P&L page saved as high-quality searchable PDF: pnl_page_searchable.pdf
# 'pnl_page_searchable.pdf'
